# %% [markdown]
# <a href="https://colab.research.google.com/github/sarbojitdas/myproject/blob/main/Anomaly_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# ## Read different Dataset and combine to a single dataset and preprocess the data

# %%
df1=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-01-00-00-00-e.csv')
df2=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-04-00-00-00-e.csv')
df3=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-07-00-00-00-e.csv')
df4=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-10-00-00-00-e.csv')
df5=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-13-00-00-00-e.csv')
df6=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-16-00-00-00-e.csv')
df7=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-19-00-00-00-e.csv')
df8=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-22-00-00-00-e.csv')
df9=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-25-00-00-00-e.csv')
df10=pd.read_csv('/content/drive/MyDrive/anomalies/2021-06-28-00-00-00-e.csv')

# %%
dx1=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10],ignore_index=True)
dx1
# Out:
#            Time stamp  Main  - Total  (kWh)  \
# 0    2021-06-01 00:00                 14.82
# 1    2021-06-01 01:00                 21.24
# 2    2021-06-01 02:00                 11.00
# 3    2021-06-01 03:00                  8.92
# 4    2021-06-01 04:00                  8.91
# ..                ...                   ...
# 715  2021-06-30 19:00                 19.20
# 716  2021-06-30 20:00                 17.26
# 717  2021-06-30 21:00                 17.88
# 718  2021-06-30 22:00                 17.42
# 719  2021-06-30 23:00                 16.60
#
#      LCC Oxford Circus temperatures (℃)
# 0                                 13.28
# 1                                 12.56
# 2                                 12.06
# 3                                 11.57
# 4                                 11.71
# ..                                  ...
# 715                               16.96
# 716                               16.41
# 717                               15.53
# ...

# %%
df1=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-01-00-00-00-e.csv')
df2=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-04-00-00-00-e.csv')
df3=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-07-00-00-00-e.csv')
df4=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-10-00-00-00-e.csv')
df5=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-13-00-00-00-e.csv')
df6=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-16-00-00-00-e.csv')
df7=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-19-00-00-00-e.csv')
df8=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-22-00-00-00-e.csv')
df9=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-25-00-00-00-e.csv')
df10=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-28-00-00-00-e.csv')

# %%
dx2=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10],ignore_index=True)
dx2
# Out:
#            Time stamp  Main  - Total  (kWh)  \
# 0    2021-07-01 00:00                 14.70
# 1    2021-07-01 01:00                  9.15
# 2    2021-07-01 02:00                  4.98
# 3    2021-07-01 03:00                  5.54
# 4    2021-07-01 04:00                  5.13
# ..                ...                   ...
# 715  2021-07-30 19:00                 23.79
# 716  2021-07-30 20:00                 25.58
# 717  2021-07-30 21:00                 27.04
# 718  2021-07-30 22:00                 26.96
# 719  2021-07-30 23:00                 27.14
#
#      LCC Oxford Circus temperatures (℃)
# 0                                 13.71
# 1                                 12.92
# 2                                 12.42
# 3                                 12.50
# 4                                 12.09
# ..                                  ...
# 715                               16.82
# 716                               16.31
# 717                               16.05
# ...

# %%
df1=pd.read_csv('/content/drive/MyDrive/anomalies/2021-07-31-00-00-00-e-2.csv')
df2=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-03-00-00-00-e-2.csv')
df3=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-06-00-00-00-e-2.csv')
df4=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-09-00-00-00-e-2.csv')
df5=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-12-00-00-00-e-2.csv')
df6=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-15-00-00-00-e-2.csv')
df7=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-18-00-00-00-e-2.csv')
df8=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-21-00-00-00-e-2.csv')
df9=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-24-00-00-00-e.csv')
df10=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-27-00-00-00-e.csv')
df11=pd.read_csv('/content/drive/MyDrive/anomalies/2021-08-30-00-00-00-e.csv')

# %%
dx3=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11],ignore_index=True)
dx3
# Out:
#            Time stamp  Main  - Total  (kWh)  \
# 0    2021-07-31 00:00                 27.67
# 1    2021-07-31 01:00                 26.70
# 2    2021-07-31 02:00                 26.07
# 3    2021-07-31 03:00                 18.88
# 4    2021-07-31 04:00                  9.87
# ..                ...                   ...
# 763  2021-08-31 19:00                 18.64
# 764  2021-08-31 20:00                 19.42
# 765  2021-08-31 21:00                 18.39
# 766  2021-08-31 22:00                 19.22
# 767  2021-08-31 23:00                 17.95
#
#      LCC Oxford Circus temperatures (℃)
# 0                                 14.64
# 1                                 14.14
# 2                                 13.79
# 3                                 13.48
# 4                                 13.59
# ..                                  ...
# 763                               16.09
# 764                               15.51
# 765                               15.03
# ...

# %%
df=pd.concat([dx1,dx2,dx3],ignore_index=True)
df
# Out:
#             Time stamp  Main  - Total  (kWh)  \
# 0     2021-06-01 00:00                 14.82
# 1     2021-06-01 01:00                 21.24
# 2     2021-06-01 02:00                 11.00
# 3     2021-06-01 03:00                  8.92
# 4     2021-06-01 04:00                  8.91
# ...                ...                   ...
# 2203  2021-08-31 19:00                 18.64
# 2204  2021-08-31 20:00                 19.42
# 2205  2021-08-31 21:00                 18.39
# 2206  2021-08-31 22:00                 19.22
# 2207  2021-08-31 23:00                 17.95
#
#       LCC Oxford Circus temperatures (℃)
# 0                                  13.28
# 1                                  12.56
# 2                                  12.06
# 3                                  11.57
# 4                                  11.71
# ...                                  ...
# 2203                               16.09
# 2204                               15.51
# 2205                               15.03
# ...

# %%
df.columns=['timestamp','energy','temperature']
df
# Out:
#              timestamp  energy  temperature
# 0     2021-06-01 00:00   14.82        13.28
# 1     2021-06-01 01:00   21.24        12.56
# 2     2021-06-01 02:00   11.00        12.06
# 3     2021-06-01 03:00    8.92        11.57
# 4     2021-06-01 04:00    8.91        11.71
# ...                ...     ...          ...
# 2203  2021-08-31 19:00   18.64        16.09
# 2204  2021-08-31 20:00   19.42        15.51
# 2205  2021-08-31 21:00   18.39        15.03
# 2206  2021-08-31 22:00   19.22        14.74
# 2207  2021-08-31 23:00   17.95        14.63
#
# [2208 rows x 3 columns]

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df
# Out:
#                timestamp  energy  temperature
# 0    2021-06-01 00:00:00   14.82        13.28
# 1    2021-06-01 01:00:00   21.24        12.56
# 2    2021-06-01 02:00:00   11.00        12.06
# 3    2021-06-01 03:00:00    8.92        11.57
# 4    2021-06-01 04:00:00    8.91        11.71
# ...                  ...     ...          ...
# 2203 2021-08-31 19:00:00   18.64        16.09
# 2204 2021-08-31 20:00:00   19.42        15.51
# 2205 2021-08-31 21:00:00   18.39        15.03
# 2206 2021-08-31 22:00:00   19.22        14.74
# 2207 2021-08-31 23:00:00   17.95        14.63
#
# [2208 rows x 3 columns]

# %% [markdown]
# Des

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    2208 non-null   datetime64[ns]
#  1   energy       2208 non-null   float64
#  2   temperature  2208 non-null   float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 51.9 KB

# %%
df.describe()
# Out:
#             energy  temperature
# count  2208.000000   2208.00000
# mean     12.548637     17.71212
# std       6.966479      3.67903
# min       0.000000      7.38000
# 25%       6.800000     15.12750
# 50%      11.640000     17.12000
# 75%      18.645000     19.96000
# max      27.670000     30.61000

# %%
df['hour']=df.timestamp.dt.hour

# %%
df
# Out:
#                timestamp  energy  temperature  hour
# 0    2021-06-01 00:00:00   14.82        13.28     0
# 1    2021-06-01 01:00:00   21.24        12.56     1
# 2    2021-06-01 02:00:00   11.00        12.06     2
# 3    2021-06-01 03:00:00    8.92        11.57     3
# 4    2021-06-01 04:00:00    8.91        11.71     4
# ...                  ...     ...          ...   ...
# 2203 2021-08-31 19:00:00   18.64        16.09    19
# 2204 2021-08-31 20:00:00   19.42        15.51    20
# 2205 2021-08-31 21:00:00   18.39        15.03    21
# 2206 2021-08-31 22:00:00   19.22        14.74    22
# 2207 2021-08-31 23:00:00   17.95        14.63    23
#
# [2208 rows x 4 columns]

# %%
df['week']=pd.Categorical(df.timestamp.dt.strftime('%A'),categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])

# %%
df.head(35)
# Out:
#              timestamp  energy  temperature  hour       week
# 0  2021-06-01 00:00:00   14.82        13.28     0    Tuesday
# 1  2021-06-01 01:00:00   21.24        12.56     1    Tuesday
# 2  2021-06-01 02:00:00   11.00        12.06     2    Tuesday
# 3  2021-06-01 03:00:00    8.92        11.57     3    Tuesday
# 4  2021-06-01 04:00:00    8.91        11.71     4    Tuesday
# 5  2021-06-01 05:00:00    7.19        11.42     5    Tuesday
# 6  2021-06-01 06:00:00    6.27        12.63     6    Tuesday
# 7  2021-06-01 07:00:00    8.14        15.15     7    Tuesday
# 8  2021-06-01 08:00:00    7.38        17.67     8    Tuesday
# 9  2021-06-01 09:00:00    4.75        20.56     9    Tuesday
# 10 2021-06-01 10:00:00    6.80        22.52    10    Tuesday
# 11 2021-06-01 11:00:00    7.58        24.17    11    Tuesday
# 12 2021-06-01 12:00:00    6.86        24.36    12    Tuesday
# 13 2021-06-01 13:00:00    5.35        24.76    13    Tuesday
# ...

# %% [markdown]
# ## Descriptive analysis of the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2208 entries, 0 to 2207
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    2208 non-null   datetime64[ns]
#  1   energy       2208 non-null   float64
#  2   temperature  2208 non-null   float64
#  3   hour         2208 non-null   int64
#  4   week         2208 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(2), int64(1)
# memory usage: 71.6 KB

# %%
df.describe() # shows count, mean, standard deviation for each column
# Out:
#             energy  temperature  ...  week_of_year   is_weekday
# count  2208.000000   2208.00000  ...   2208.000000  2208.000000
# mean     12.548637     17.71212  ...     28.217391     3.978261
# std       6.966479      3.67903  ...      3.805396     2.000335
# min       0.000000      7.38000  ...     22.000000     1.000000
# 25%       6.800000     15.12750  ...     25.000000     2.000000
# 50%      11.640000     17.12000  ...     28.000000     4.000000
# 75%      18.645000     19.96000  ...     31.250000     6.000000
# max      27.670000     30.61000  ...     35.000000     7.000000
#
# [8 rows x 7 columns]

# %%
df.max() # find the maximum value
# Out:
# energy              27.67
# temperature         30.61
# hour                   23
# day                    31
# day_name        Wednesday
# day_of_year           243
# week_of_year           35
# is_weekday              7
# dtype: object

# %%
df.min() #find the minimum value
# Out:
# energy               0
# temperature       7.38
# hour                 0
# day                  1
# day_name        Friday
# day_of_year        152
# week_of_year        22
# is_weekday           1
# dtype: object

# %%
df.mean() # find the mean value of the rows
# Out:
# energy           12.548637
# temperature      17.712120
# hour             11.500000
# day              15.836957
# day_of_year     197.500000
# week_of_year     28.217391
# is_weekday        3.978261
# dtype: float64

# %%
df.median() #find the median value of the rows
# Out:
# energy           11.64
# temperature      17.12
# hour             11.50
# day              16.00
# day_of_year     197.50
# week_of_year     28.00
# is_weekday        4.00
# dtype: float64

# %%
df.mode() #find the mode of the rows
# Out:
#     energy  temperature  hour  ...  day_of_year week_of_year  is_weekday
# 0      0.0        16.31   0.0  ...          152         23.0         2.0
# 1      NaN        17.11   1.0  ...          153         24.0         NaN
# 2      NaN          NaN   2.0  ...          154         25.0         NaN
# 3      NaN          NaN   3.0  ...          155         26.0         NaN
# 4      NaN          NaN   4.0  ...          156         27.0         NaN
# ..     ...          ...   ...  ...          ...          ...         ...
# 87     NaN          NaN   NaN  ...          239          NaN         NaN
# 88     NaN          NaN   NaN  ...          240          NaN         NaN
# 89     NaN          NaN   NaN  ...          241          NaN         NaN
# 90     NaN          NaN   NaN  ...          242          NaN         NaN
# 91     NaN          NaN   NaN  ...          243          NaN         NaN
#
# [92 rows x 8 columns]

# %%
df.std() #find the standard deviation of the rows
# Out:
# energy           6.966479
# temperature      3.679030
# hour             6.923755
# day              8.856232
# day_of_year     26.562559
# week_of_year     3.805396
# is_weekday       2.000335
# dtype: float64

# %%
df.corr(method='pearson')#find the correlance of the vaiables using pearson method
# Out:
#                 energy  temperature  ...  week_of_year    is_weekday
# energy        1.000000     0.152188  ...  2.357215e-01  2.278872e-01
# temperature   0.152188     1.000000  ... -9.917247e-02 -1.118450e-02
# hour          0.383659     0.393196  ...  3.665790e-18 -1.208779e-17
# day           0.099021    -0.071197  ...  3.550224e-01 -1.800161e-02
# day_of_year   0.253550    -0.100296  ...  9.971765e-01  3.635520e-18
# week_of_year  0.235722    -0.099172  ...  1.000000e+00 -7.509393e-02
# is_weekday    0.227887    -0.011185  ... -7.509393e-02  1.000000e+00
#
# [7 rows x 7 columns]

# %%
df.corr(method='spearman')#find the correlation of the variables using spearman method
# Out:
#                 energy  temperature  ...  week_of_year  is_weekday
# energy        1.000000     0.174202  ...      0.226934    0.226647
# temperature   0.174202     1.000000  ...     -0.074374    0.005525
# hour          0.383450     0.433391  ...      0.000000    0.000000
# day           0.091984    -0.068722  ...      0.351690   -0.018208
# day_of_year   0.243416    -0.075245  ...      0.997268   -0.000506
# week_of_year  0.226934    -0.074374  ...      1.000000   -0.073137
# is_weekday    0.226647     0.005525  ...     -0.073137    1.000000
#
# [7 rows x 7 columns]

# %%
df.cov() #find the covariance of the rows
# Out:
#                  energy  temperature  ...  week_of_year    is_weekday
# energy        48.531832     3.900565  ...      6.249028  3.175675e+00
# temperature    3.900565    13.535263  ...     -1.388431 -8.231004e-02
# hour          18.505480    10.015759  ...      0.000000  5.151193e-17
# day            6.109293    -2.319763  ...     11.964776 -3.189062e-01
# day_of_year   46.918870    -9.801328  ...    100.795650  8.241909e-16
# week_of_year   6.249028    -1.388431  ...     14.481039 -5.716199e-01
# is_weekday     3.175675    -0.082310  ...     -0.571620  4.001340e+00
#
# [7 rows x 7 columns]

# %%
df.skew() #skew
# Out:
# energy          0.203133
# temperature     0.731049
# hour            0.000000
# day             0.002402
# day_of_year     0.000000
# week_of_year    0.006436
# is_weekday      0.021755
# dtype: float64

# %%
corr = df.corr() 

fig = plt.figure(figsize=(10,10))

sns.heatmap(corr, vmax=.8, square=True,annot=True)

# %% [markdown]
# ## Visualization of datapoints

# %%
df[['energy','temperature','week_of_year']].groupby('week_of_year').mean().plot()

# %%
df[['energy','temperature','hour']].groupby('hour').mean().plot()

# %%
fig=px.line(df.reset_index(),x='timestamp',y='energy',title='Energy Consumption')
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="860f1903-01c8-4c07-9aef-b7008c164be9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("860f1903-01c8-4c07-9aef-b7008c164be9")) {
#                     Plotly.newPlot(
#                         '860f1903-01c8-4c07-9aef-b7008c164be9',
# ...

# %% [markdown]
# ## Visualization of the outlier

# %%
plt.boxplot(df['energy'])
plt.show()

# %%
df['energy'].hist()

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(df['day'], df['energy'])
ax.set_xlabel('timestamp')
ax.set_ylabel('energy')
plt.show()

# %% [markdown]
# ## Calculating moving average and applying on the dataset

# %%
# create moving-averages
df['MA48'] = df['energy'].rolling(48).mean()
df['MA336'] = df['energy'].rolling(336).mean()
# plot 
df
# Out:
#                      energy  temperature  ...       MA48      MA336
# timestamp                                 ...
# 2021-06-01 00:00:00   14.82        13.28  ...        NaN        NaN
# 2021-06-01 01:00:00   21.24        12.56  ...        NaN        NaN
# 2021-06-01 02:00:00   11.00        12.06  ...        NaN        NaN
# 2021-06-01 03:00:00    8.92        11.57  ...        NaN        NaN
# 2021-06-01 04:00:00    8.91        11.71  ...        NaN        NaN
# ...                     ...          ...  ...        ...        ...
# 2021-08-31 19:00:00   18.64        16.09  ...  12.925417  15.542232
# 2021-08-31 20:00:00   19.42        15.51  ...  12.901042  15.536369
# 2021-08-31 21:00:00   18.39        15.03  ...  12.847083  15.527083
# 2021-08-31 22:00:00   19.22        14.74  ...  12.783333  15.517917
# 2021-08-31 23:00:00   17.95        14.63  ...  12.701042  15.505774
#
# [2208 rows x 10 columns]

# %%
# drop moving-average columns
df.drop(['MA48', 'MA336'], axis=1, inplace=True)
# set timestamp to index
#df.set_index('timestamp', drop=True, inplace=True)
# resample timeseries to hourly 
df = df.resample('H').sum()
# creature features from date
df['day'] = [i.day for i in df.index]
df['day_name'] = [i.day_name() for i in df.index]
df['day_of_year'] = [i.dayofyear for i in df.index]
df['week_of_year'] = [i.weekofyear for i in df.index]
df['hour'] = [i.hour for i in df.index]
df['is_weekday'] = [i.isoweekday() for i in df.index]
df.head()
# Out:
#                      energy  temperature  ...  is_weekday  day_name
# timestamp                                 ...
# 2021-06-01 00:00:00   14.82        13.28  ...           2   Tuesday
# 2021-06-01 01:00:00   21.24        12.56  ...           2   Tuesday
# 2021-06-01 02:00:00   11.00        12.06  ...           2   Tuesday
# 2021-06-01 03:00:00    8.92        11.57  ...           2   Tuesday
# 2021-06-01 04:00:00    8.91        11.71  ...           2   Tuesday
#
# [5 rows x 8 columns]

# %% [markdown]
# ## Description of the dataset

# %%
s = setup(df, session_id = 123)
# Out:
#                                Description                 Value
# 0                               session_id                   123
# 1                            Original Data             (2208, 8)
# 2                           Missing Values                 False
# 3                         Numeric Features                     5
# 4                     Categorical Features                     3
# 5                         Ordinal Features                 False
# 6                High Cardinality Features                 False
# 7                  High Cardinality Method                  None
# 8                         Transformed Data            (2208, 33)
# 9                                 CPU Jobs                    -1
# 10                                 Use GPU                 False
# 11                          Log Experiment                 False
# 12                         Experiment Name  anomaly-default-name
# ...

# %%
models()
# Out:
#                                         Name                    Reference
# ID
# abod            Angle-base Outlier Detection        pyod.models.abod.ABOD
# cluster       Clustering-Based Local Outlier      pyod.models.cblof.CBLOF
# cof         Connectivity-Based Local Outlier          pyod.models.cof.COF
# iforest                     Isolation Forest  pyod.models.iforest.IForest
# histogram  Histogram-based Outlier Detection        pyod.models.hbos.HBOS
# knn             K-Nearest Neighbors Detector          pyod.models.knn.KNN
# lof                     Local Outlier Factor          pyod.models.lof.LOF
# svm                   One-class SVM detector      pyod.models.ocsvm.OCSVM
# pca             Principal Component Analysis          pyod.models.pca.PCA
# mcd           Minimum Covariance Determinant          pyod.models.mcd.MCD
# sod               Subspace Outlier Detection          pyod.models.sod.SOD
# sos             Stochastic Outlier Selection          pyod.models.sos.SOS

# %% [markdown]
# ## Local Outlier Factor

# %%
# train model
lof = create_model('lof', fraction = 0.26)
lof_results = assign_model(lof)
lof_results.head()
# Out:
#                      energy  temperature  ...  Anomaly  Anomaly_Score
# timestamp                                 ...
# 2021-06-01 00:00:00   14.82        13.28  ...        1       1.076968
# 2021-06-01 01:00:00   21.24        12.56  ...        1       1.243311
# 2021-06-01 02:00:00   11.00        12.06  ...        1       1.069838
# 2021-06-01 03:00:00    8.92        11.57  ...        1       1.068313
# 2021-06-01 04:00:00    8.91        11.71  ...        1       1.076955
#
# [5 rows x 10 columns]

# %%
# check anomalies
lof_results[lof_results['Anomaly'] == 1].head()
# Out:
#                      energy  temperature  ...  Anomaly  Anomaly_Score
# timestamp                                 ...
# 2021-06-01 00:00:00   14.82        13.28  ...        1       0.015318
# 2021-06-01 01:00:00   21.24        12.56  ...        1       0.020042
# 2021-06-01 02:00:00   11.00        12.06  ...        1       0.002360
# 2021-06-01 21:00:00   16.50        17.71  ...        1       0.000474
# 2021-06-01 22:00:00   17.30        16.31  ...        1       0.002509
#
# [5 rows x 10 columns]

# %%
import plotly.graph_objects as go
# plot energy on y-axis and date on x-axis
fig = px.line(lof_results, x=lof_results.index, y="energy", title='Energy Consumption - UNSUPERVISED ANOMALY DETECTION', template = 'plotly_dark')
# create list of outlier_dates
outlier_dates = lof_results[iforest_results['Anomaly'] == 1].index
# obtain y energy of anomalies to plot
y_energys = [lof_results.loc[i]['energy'] for i in outlier_dates]
fig.add_trace(go.Scatter(x=outlier_dates, y=y_energys, mode = 'markers', 
                name = 'Anomaly', 
                marker=dict(color='red',size=10)))
        
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2cbdbfd4-1c73-430f-b6c0-c91d66bc120e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2cbdbfd4-1c73-430f-b6c0-c91d66bc120e")) {
#                     Plotly.newPlot(
#                         '2cbdbfd4-1c73-430f-b6c0-c91d66bc120e',
# ...

# %% [markdown]
# ## Iforest

# %%
# train model
iforest = create_model('iforest', fraction = 0.26)
iforest_results = assign_model(iforest)
iforest_results.head()
# Out:
#                      energy  temperature  ...  Anomaly  Anomaly_Score
# timestamp                                 ...
# 2021-06-01 00:00:00   14.82        13.28  ...        1       0.015318
# 2021-06-01 01:00:00   21.24        12.56  ...        1       0.020042
# 2021-06-01 02:00:00   11.00        12.06  ...        1       0.002360
# 2021-06-01 03:00:00    8.92        11.57  ...        0      -0.001006
# 2021-06-01 04:00:00    8.91        11.71  ...        0      -0.002158
#
# [5 rows x 10 columns]

# %%
# check anomalies
iforest_results[iforest_results['Anomaly'] == 1].head()
# Out:
#                      energy  temperature  ...  Anomaly  Anomaly_Score
# timestamp                                 ...
# 2021-06-01 00:00:00   14.82        13.28  ...        1       0.015318
# 2021-06-01 01:00:00   21.24        12.56  ...        1       0.020042
# 2021-06-01 02:00:00   11.00        12.06  ...        1       0.002360
# 2021-06-01 21:00:00   16.50        17.71  ...        1       0.000474
# 2021-06-01 22:00:00   17.30        16.31  ...        1       0.002509
#
# [5 rows x 10 columns]

# %%
import plotly.graph_objects as go
# plot energy on y-axis and date on x-axis
fig = px.line(iforest_results, x=iforest_results.index, y="energy", title='Energy Consumption - UNSUPERVISED ANOMALY DETECTION', template = 'plotly_dark')
# create list of outlier_dates
outlier_dates = iforest_results[iforest_results['Anomaly'] == 1].index
# obtain y energy of anomalies to plot
y_energys = [iforest_results.loc[i]['energy'] for i in outlier_dates]
fig.add_trace(go.Scatter(x=outlier_dates, y=y_energys, mode = 'markers', 
                name = 'Anomaly', 
                marker=dict(color='red',size=10)))
        
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8baa00f0-612e-44da-bb53-8fd64ca8b8c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8baa00f0-612e-44da-bb53-8fd64ca8b8c1")) {
#                     Plotly.newPlot(
#                         '8baa00f0-612e-44da-bb53-8fd64ca8b8c1',
# ...
